# %%
import pandas as pd

# %%
data = pd .read_csv("carprices.csv")
data
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
data.rename(columns ={'Sell Price($)':'sell_price','Age(yrs)':'Age'})
# Out:
#     Mileage  Age  sell_price
# 0     69000    6       18000
# 1     35000    3       34000
# 2     57000    5       26100
# 3     22500    2       40000
# 4     46000    4       31500
# 5     59000    5       26750
# 6     52000    5       32000
# 7     72000    6       19300
# 8     91000    8       12000
# 9     67000    6       22000
# 10    83000    7       18700
# 11    79000    7       19500
# 12    59000    5       26000
# 13    58780    4       27500
# 14    82450    7       19400
# 15    25400    3       35000
# 16    28000    2       35500
# 17    69000    5       19700
# 18    87600    8       12800
# 19    52000    5       28200

# %%
import matplotlib.pyplot as plt
plt.scatter(data.Mileage, data['Sell Price($)'], color = 'Red')
# plt.scatter(data['Age(yrs)'],data['Sell Price($)'])

# %%
x = data[['Mileage','Age(yrs)']]
y = data[['Sell Price($)']]
# Out:
#     Sell Price($)
# 0           18000
# 1           34000
# 2           26100
# 3           40000
# 4           31500
# 5           26750
# 6           32000
# 7           19300
# 8           12000
# 9           22000
# 10          18700
# 11          19500
# 12          26000
# 13          27500
# 14          19400
# 15          35000
# 16          35500
# 17          19700
# 18          12800
# 19          28200

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2,random_state = 9)

# %%
y_test
# Out:
#    Sell Price($)
# 3          40000
# 6          32000
# 7          19300
# 5          26750

# %%
from sklearn.linear_model import LinearRegression
Lr = LinearRegression()
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Lr.predict(x_test)
# Out:
# array([[37949.92639254],
#        [27047.03642494],
#        [20714.4038076 ],
#        [25189.16576294]])

# %%
Lr.score(x_test,y_test)
# Out:
# 0.8545764184601808
